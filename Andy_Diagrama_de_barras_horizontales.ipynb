# %% [markdown]
# ### Índice
# 1. [Volver al indice](https://github.com/CristobalGachuz/Generacion_de_Graficas/blob/main/indice.ipynb)

# %%
# Importar las bibliotecas necesarias
import matplotlib.pyplot as plt

# Datos para el gráfico
categorías = ['Categoría A', 'Categoría B', 'Categoría C', 'Categoría D']
valores = [10, 15, 7, 12]

# Crear el gráfico de barras horizontales
plt.barh(categorías, valores, color='skyblue')

# Añadir títulos y etiquetas
plt.xlabel('Valores')
plt.title('Diagrama de Barras Horizontales')

# Mostrar el gráfico
plt.show()
